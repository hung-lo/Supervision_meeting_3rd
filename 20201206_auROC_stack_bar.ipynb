# %% [markdown]
# ### This notebook is used for plot stacked auROC analysis for neural responses.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.ticker import MaxNLocator
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#plt.style.use('seaborn')
import seaborn as sns

import datetime

import numpy as np
import pandas as pd
import math
from random import randrange
from random import randint

from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold

# import sys
# sys.path.append("/Users/hunglo/Dropbox/AG_Johenning_Schmitz/Programming/python/")
# import os
# from figures import plotinscopixtraces
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/hunglo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
auroc_class = pd.read_excel('/Users/hunglo/Desktop/3rd_supervision/excel_auROC/auROC_class_number_3mice.xlsx',skiprows=1)
auroc_class#.plot()

pivot_df = auroc_class.iloc[:,1:].pivot_table(
    index=['Solution'],        # Put Mouse_ID and Session to multi-index
    columns='Response',  values='Percentage')     # Put rounds to column
pivot_df

import matplotlib.lines as mlines
from matplotlib.ticker import MaxNLocator
from matplotlib.patches import Polygon

plt.style.use('seaborn')

fig,ax=plt.subplots()
pivot_df.plot(kind='bar', stacked=True,figsize=[3.25,3.5],ax=ax)
plt.text(x=0,y=90,s=15.51,ha='center',color='w')
plt.text(x=1,y=90,s=13.98,ha='center',color='w')

plt.text(x=0,y=50,s=62.83,ha='center',color='w')
plt.text(x=1,y=50,s=69.59,ha='center',color='w')

plt.text(x=0,y=5,s=21.66,ha='center',color='w')
plt.text(x=1,y=5,s=16.44,ha='center',color='w')

plt.ylabel('%',fontsize=10)

plt.title('Strawberry recordings (n=651/N=3)',fontsize=10)

ax.legend(bbox_to_anchor=(0., -0.2, 1., -0.2), loc=4, ncol=3, mode="expand", borderaxespad=0.,fontsize=8,frameon=False)

# ax.text(x=0,y=20,s='sss')

#plt.legend(title='Response',loc=1,fontsize=8,frameon=True)
plt.xticks(rotation=0)
plt.xlabel(None)
plt.tight_layout()
plt.savefig('/Users/hunglo/Desktop/3rd_supervision/auROC/auROC_class_percentage.pdf',dpi=300)
